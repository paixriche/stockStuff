# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

import yfinance as yf
from googlesearch import search

plt.style.use('seaborn')

# %%
msft = yf.Ticker("MSFT")
df_msft = msft.history(period="max")
print(df_msft)

plt.figure()
plt.plot(df_msft)
plt.show()
# Out:
#                   Open        High         Low       Close      Volume  \
# Date
# 1986-03-13    0.056001    0.064236    0.056001    0.061491  1031788800
# 1986-03-14    0.061491    0.064785    0.061491    0.063687   308160000
# 1986-03-17    0.063687    0.065334    0.063687    0.064785   133171200
# 1986-03-18    0.064785    0.065334    0.062589    0.063138    67766400
# 1986-03-19    0.063138    0.063687    0.061491    0.062040    47894400
# ...                ...         ...         ...         ...         ...
# 2021-10-29  324.130005  332.000000  323.899994  331.619995    34744900
# 2021-11-01  331.359985  331.489990  326.369995  329.369995    27073200
# 2021-11-02  330.309998  333.450012  330.000000  333.130005    26487100
# 2021-11-03  333.899994  334.899994  330.649994  334.000000    21485300
# 2021-11-04  332.890015  336.540009  329.510010  336.440002    23907365
#
#             Dividends  Stock Splits
# Date
# 1986-03-13        0.0           0.0
# 1986-03-14        0.0           0.0
# 1986-03-17        0.0           0.0
# 1986-03-18        0.0           0.0
# 1986-03-19        0.0           0.0
# ...               ...           ...
# 2021-10-29        0.0           0.0
# 2021-11-01        0.0           0.0
# 2021-11-02        0.0           0.0
# 2021-11-03        0.0           0.0
# 2021-11-04        0.0           0.0
#
# [8987 rows x 7 columns]

# %%
# Return the ticker of a company by using google search api
def tickerOfCompany(companyName):
    result = search("Yahoo Finance " + companyName)
    result = result[0].lower()
    return result.split('/')[-2]

# %%
print(tickerOfCompany('Microsoft'))
# Out:
# msft

# %%
def stockHistory(companyName, period='max'):
    ticker = tickerOfCompany(companyName)
    company = yf.Ticker(ticker)
    
    df = company.history(period)
    
    stockPriceStart = 0
    stockPriceEnd = 0
    
    currentPrice = company.info['currentPrice']
    
    return df

# %%
df = stockChange('Microsoft')

plt.figure()
plt.plot(df['Close'])
plt.show()
